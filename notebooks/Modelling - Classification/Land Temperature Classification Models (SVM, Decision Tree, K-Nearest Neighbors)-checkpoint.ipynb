# %%
# load csv into pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:\\Users\\Ronald\\Documents\\EECS_731\\Project\\mergedData.csv')
df.head()
# Out:
#    year  SeaLevel        Coal       Oil       Gas  CO2-Concentration  \
# 0  1900    -130.1  5727.78236  180.5557  63.88894         1880.29881
# 1  1901    -130.5  5727.78236  180.5557  63.88894         1942.99709
# 2  1902    -125.9  5727.78236  180.5557  63.88894         1996.90205
# 3  1903    -117.9  5727.78236  180.5557  63.88894         2186.94199
# 4  1904    -128.2  5727.78236  180.5557  63.88894         2202.66794
#
#    TempGlobal  TempLand
# 0   15.143917  8.501583
# 1   15.073333  8.541917
# 2   14.958333  8.304417
# 3   14.836583  8.220167
# 4   14.810417  8.090917

# %%
df.loc[df['TempLand'].idxmax()]
# Out:
# year                   2015.000000
# SeaLevel                 67.700000
# Coal                  44015.530330
# Oil                   50485.326930
# Gas                   36596.658820
# CO2-Concentration    179639.070000
# TempGlobal               16.058583
# TempLand                  9.831000
# Name: 115, dtype: float64

# %%
# place years into bins
# categorize tempglobal data
from sklearn import preprocessing

tg_labels = [0,1,2,3,4,5]
df['TempLand_bins'] = pd.cut(df['TempLand'], 6, labels=tg_labels, include_lowest=True)

df = df[['year','SeaLevel','Coal','Oil','Gas','CO2-Concentration','TempGlobal','TempLand_bins','TempLand']]
df.head()
# Out:
#    year  SeaLevel        Coal       Oil       Gas  CO2-Concentration  \
# 0  1900    -130.1  5727.78236  180.5557  63.88894         1880.29881
# 1  1901    -130.5  5727.78236  180.5557  63.88894         1942.99709
# 2  1902    -125.9  5727.78236  180.5557  63.88894         1996.90205
# 3  1903    -117.9  5727.78236  180.5557  63.88894         2186.94199
# 4  1904    -128.2  5727.78236  180.5557  63.88894         2202.66794
#
#    TempGlobal TempLand_bins  TempLand
# 0   15.143917             1  8.501583
# 1   15.073333             1  8.541917
# 2   14.958333             1  8.304417
# 3   14.836583             0  8.220167
# 4   14.810417             0  8.090917

# %%
# run pairplot on data
pp = sns.pairplot(df, hue='TempLand_bins', vars=['year','SeaLevel','Coal','Oil','Gas','CO2-Concentration'])

# %%
# create training and test sets for classification models
from sklearn.model_selection import train_test_split

# create training sets and test sets (80-20 split)
# sealevel and global temperature features look promising
X = df[['Gas', 'Coal']].values
y = df['TempLand_bins']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Classification Model Code Inspired By 
# https://towardsdatascience.com/solving-a-simple-classification-problem-with-python-fruits-lovers-edition-d20ab6b071d2

# %%
# Linear SVM classifier
from sklearn.svm import SVC

svm = SVC(kernel='linear')

# train model with training sets
svm.fit(X_train, y_train)

# check accuracy of support vector machine classification model
print('Accuracy of SVM classifier on training set: {:.2f}'.format(svm.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.2f}'.format(svm.score(X_test, y_test)))
# Out:
# Accuracy of SVM classifier on training set: 0.61
# Accuracy of SVM classifier on test set: 0.50

# %%
# Decision Tree Classifier
from sklearn import tree
dt = tree.DecisionTreeClassifier()
dt = dt.fit(X_train, y_train)

# check accuracy of decision tree classification model
print('Accuracy of Decision Tree classifier on training set: {:.2f}'.format(dt.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'.format(dt.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.85
# Accuracy of Decision Tree classifier on test set: 0.58

# %%
# K-Nearest Neighbors Classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)

# check accuracy of k-nearest neighbors classification model
print('Accuracy of K-NN classifier on training set: {:.2f}'.format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'.format(knn.score(X_test, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.64
# Accuracy of K-NN classifier on test set: 0.50

# %%
# Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# check accuracy of gaussian naive bayes classification model
print('Accuracy of GNB classifier on training set: {:.2f}'.format(gnb.score(X_train, y_train)))
print('Accuracy of GNB classifier on test set: {:.2f}'.format(gnb.score(X_test, y_test)))
# Out:
# Accuracy of GNB classifier on training set: 0.51
# Accuracy of GNB classifier on test set: 0.54

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)

# check accuracy of logistic regression classification model
print('Accuracy of Logistic regression classifier on training set: {:.2f}'.format(logreg.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.53
# Accuracy of Logistic regression classifier on test set: 0.46
